# %%
import pyodbc
import pandas as pd
import matplotlib.pyplot as plt

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-C269BOM\MSSQLSERVER01;'
                      'Database=AdventureWorks2019;'
                      'Trusted_Connection=yes;')

# %%
cursor = conn.cursor()

# %%
query = 'SELECT * FROM [dbo].[store_duration_revenue]'

# %%
tradedata = pd.read_sql(query, conn)
# Out:
# C:\Users\owenc\AppData\Local\Temp\ipykernel_19200\1879931722.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tradedata = pd.read_sql(query, conn)

# %%
print(tradedata.head())
# Out:
#                     StoreName  YearOpened  TradingDuration  YearlyRevenue  \
# 0                A Bike Store        1970               53        30000.0
# 1     A Great Bicycle Company        1971               52       100000.0
# 2         A Typical Bike Shop        1982               41        30000.0
# 3  Acceptable Sales & Service        1988               35        80000.0
# 4         Accessories Network        1984               39        80000.0
#
#       Revenue
# 0  95924.0197
# 1  10196.1966
# 2  93981.0186
# 3   1416.9322
# 4   2450.4786

# %%
tradedata.plot.scatter(x='TradingDuration', y='YearlyRevenue', xlabel='Store Trade Duration (Years)', ylabel='Yearly Revenue', title='Relationship Between Trade Duration and Yearly Revenue', s=80, alpha=0.1)
# Out:
# <Axes: title={'center': 'Relationship Between Trade Duration and Yearly Revenue'}, xlabel='Store Trade Duration (Years)', ylabel='Yearly Revenue'>

# %%
tradedata.plot.scatter(x='TradingDuration', y='Revenue', xlabel='Store Trade Duration (Years)', ylabel='Overall Revenue (1e6 = 1 million)', title='Relationship Between Trade Duration and Overall Revenue', alpha=0.3, s=60)
# Out:
# <Axes: title={'center': 'Relationship Between Trade Duration and Overall Revenue'}, xlabel='Store Trade Duration (Years)', ylabel='Overall Revenue (1e6 = 1 million)'>
