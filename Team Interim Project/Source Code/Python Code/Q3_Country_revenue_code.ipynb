# %% [markdown]
# Import the neccessary package

# %%
import pyodbc as pc
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Establish neccessary connection

# %%
conn = pc.connect('Driver={SQL Server};'
                  'Server=DESKTOP-CO3SDLU\MSSQLSERVER01;'
                  'Database=AdventureWorks2019;'
                  'Trusted_Connection=yes;')

# %% [markdown]
# create the cusor

# %%
cursor = conn.cursor()

# %% [markdown]
# Create the query

# %%
query = 'SELECT* FROM [dbo].[Country_Revenue]'

# %% [markdown]
# Read query into pandas and assigned apropraite name

# %%
country_revenue = pd.read_sql(query,conn)
# Out:
# C:\Users\Generation UK&I\AppData\Local\Temp\ipykernel_1772\2560883853.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   country_revenue = pd.read_sql(query,conn)

# %% [markdown]
# Explore the data

# %%
print(country_revenue.head())
# Out:
#      Country       Revenue
# 0  Northwest  1.118588e+07
# 1  Northeast  6.009326e+06
# 2    Central  6.277189e+06
# 3  Southwest  1.587743e+07
# 4  Southeast  6.463739e+06

# %% [markdown]
# Visualise the data

# %%
revenue= country_revenue['Revenue']
revenue_m = revenue/1e6
country = country_revenue['Country']

# %%
plt.barh(country, revenue_m,color=('Blue', 'Blue','Blue','Orange','Blue','Blue','Blue','Blue','Blue','Blue'))
plt.title('Country VS Revenue', fontsize= 18, color= 'Black')
plt.xlabel('Revenue (M $)', fontsize= 18, color= 'Black')
plt.ylabel('Country', fontsize= 18, color= 'Black')
plt.show()

# %%
# plt.pie(revenue,  labels = country)
revenue= country_revenue['Revenue']
revenue_m = revenue/100
country = ["Northwest", "Northeast", "Central", "Southwest",'Southeast','Canada','France','Germany','Australia','United kingdom']
plt.pie(revenue,autopct='%1.0f%%', pctdistance=0.9)
plt.legend(country, bbox_to_anchor=(0.85,1.025), loc="upper left")
plt.show()
