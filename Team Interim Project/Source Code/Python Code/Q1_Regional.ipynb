# %%
import pyodbc
import pandas as pd
import matplotlib.pyplot as plt

# %%
conn = pyodbc.connect('Driver={SQL Server};' 
                      'Server=DESKTOP-3JKKF7H;'  
                      'Database=AdventureWorks2019;' 
                      'Trusted_Connection=yes;')

# %%
cursor = conn.cursor()

# %%
query = 'SELECT * FROM Regional'
regional = pd.read_sql(query, conn)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20644\2567934793.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   regional = pd.read_sql(query, conn)

# %%
print(regional.head())
# Out:
#       Region         Sales
# 0  Southwest  2.418461e+07
# 1  Northwest  1.608494e+07
# 2    Central  7.909009e+06
# 3  Southeast  7.879655e+06
# 4  Northeast  6.939374e+06

# %%
sales_m = regional['Sales']/1e6
x = regional['Region']
plt.barh(x, sales_m, color = ('blue', 'grey', 'grey', 'grey', 'grey' ))
plt.title('Regional sales in the US')
plt.xlabel('Sales M')
# Out:
# Text(0.5, 0, 'Sales M')

# %%
plt.show()
